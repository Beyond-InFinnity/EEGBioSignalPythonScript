# %%
import numpy as np
import pandas as pd
import missingno as msno
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_json("H10_log_20250611_2133.json")

# %%
msno.matrix(df)
plt.show()

# %%
df.describe()
# Out:
#                  ts           hr
# count  3.120000e+03  3120.000000
# mean   1.749701e+09    76.195833
# std    9.007849e+02     2.538788
# min    1.749700e+09    69.000000
# 25%    1.749700e+09    75.000000
# 50%    1.749701e+09    76.000000
# 75%    1.749702e+09    78.000000
# max    1.749703e+09    86.000000

# %%
df['rr'].head()
# Out:
# 0         [791]
# 1         [755]
# 2    [751, 747]
# 3         [759]
# 4         [773]
# Name: rr, dtype: object
